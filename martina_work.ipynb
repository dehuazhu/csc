# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
martina_homework = pd.read_csv("martina_homework.csv")

# %%
martina_homework.corr()
# Out:
#                              Species_2012  Species_2017  \
# Species_2012                     1.000000      0.651564
# Species_2017                     0.651564      1.000000
# Red_List_2012 (coefficient)      0.215153      0.184460
# Red_List_2017 (coefficient)      0.022677      0.336886
# Priority_2012 (coefficient)      0.659238      0.578495
# Priority_2017 (coefficient)      0.595426      0.749564
# AEO/UZL_2012 (raw number)       -0.105351     -0.130433
# AEO/UZL_2017 (raw number)       -0.331913     -0.079799
# land_use_intensity_2015          0.220818      0.073909
# Plant_diversity_2015            -0.280257     -0.053147
# ECA_all_2012                    -0.336619     -0.234322
# ECA_all_2017                    -0.323936     -0.186161
# ECA_extensive_2012              -0.299654     -0.223389
# ECA_extensive_2017              -0.268061     -0.173909
# ECA_little_intensive_2012       -0.062950      0.017325
# ECA_little_intensive_2017       -0.080656      0.029596
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(martina_homework.corr())
plt.savefig('correlation.pdf')

# %%
martina_homework.corr().to_csv(index=False)
# Out:
# 'Species_2012,Species_2017,Red_List_2012 (coefficient),Red_List_2017 (coefficient),Priority_2012 (coefficient),Priority_2017 (coefficient),AEO/UZL_2012 (raw number),AEO/UZL_2017 (raw number),land_use_intensity_2015,Plant_diversity_2015,ECA_all_2012,ECA_all_2017,ECA_extensive_2012,ECA_extensive_2017,ECA_little_intensive_2012,ECA_little_intensive_2017,ECA_wet_2012,ECA_wet_2017,Orchards_2012,Orchards_2017,connectivity,connectivity_stand\n1.0,0.6515638729262061,0.21515309657859974,0.022676754796106653,0.65923784729379,0.5954261269321143,-0.10535062619436435,-0.3319133873012251,0.2208183608077206,-0.28025694202583,-0.33661870924157933,-0.3239363826530584,-0.29965385790595755,-0.2680606089708486,-0.06295041683040634,-0.08065582665069986,-0.11457384319551568,-0.10300918522643927,-0.16835665997219654,-0.06818111746997668,0.33982884008542563,0.10300628469860643\n0.6515638729262061,1.0,0.18445987546347886,0.3368856320620757,0.5784950402749471,0.7495636506648393,-0.1304329416474375,-0.079798700
# ...

# %%
martina_homework.to_csv('out.csv', index=False)
